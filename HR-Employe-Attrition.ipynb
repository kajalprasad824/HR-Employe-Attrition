# %%
#importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#display all the columns of the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
#loading the data
dataset=pd.read_csv('HR-Employee-Attrition.csv')

# %%
#print shape of dataset with rows and columns
print(dataset.shape)
# Out:
# (1470, 35)

# %%
#print the top 5 records
dataset.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
#checking the missing values
dataset.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# there is no missing values

# %%
#checking for different tpes of datatypes
dataset.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#list of numerical variables
numerical_features  = [feature for feature in dataset.columns if dataset[feature].dtypes  != 'O']
print("Number of Numerical Variable",len(numerical_features))
# Out:
# Number of Numerical Variable 26

# %%
#visualise the numerical variables
dataset[numerical_features].head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# ...

# %%
#Numerical variables are usuall of 2 types 
#1-Discrete variable
#2-Continuous variable
discrete_feature=[feature for feature in numerical_features if len(dataset[feature].unique())<30]
print("Discrete Variable Count : {}".format(len(discrete_feature)))
# Out:
# Discrete Variable Count : 18

# %%
dataset[discrete_feature].head()
# Out:
#    DistanceFromHome  Education  EmployeeCount  EnvironmentSatisfaction  \
# 0                 1          2              1                        2
# 1                 8          1              1                        3
# 2                 2          2              1                        4
# 3                 3          4              1                        4
# 4                 2          1              1                        1
#
#    JobInvolvement  JobLevel  JobSatisfaction  NumCompaniesWorked  \
# 0               3         2                4                   8
# 1               2         2                2                   1
# 2               2         1                3                   6
# 3               3         1                3                   1
# 4               3         1                2                   9
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                 11                  3                         1
# ...

# %%
#Analyzing the discrete features  
for feature in discrete_feature:
    plt.figure(figsize=(10,6))
    sns.set(style = "whitegrid")
    sns.distplot(dataset[feature],kde=True)
    plt.show()
    print()

# %% [markdown]
# DistanceFromHome - Majority of employee live under 5km
#
# Education - Type 3 is more in number and then type 4 , type 5 education is the minimum
#
# EmployeeCount - Irrelevant
#
# EnvironmentSatisfaction - Most of the employees satisfied from the environment
#
# JobInvolvement - The employees are moderately involve in jobs
#
# JobLevel - Most of the employees are entry level(1,2)
#
# JobSatisfaction - Most of the employees are satisfied withtheir job
#
# NumCompaniesWorked - Most of the employees have changed once
#
# PercentSalaryHike - The average salary hike of the company for the employes lies between 11 to 15 percent
#
# PerformanceRating - Most of the employees have 3 star rating
#
# RelationshipSatisfication - highest is type 3 after that type 4
#
# StandardHours - Irrelevant
#
# StockOptionLevel - Most of the employees get the option 0 and 1
#
# TrainingTimeLastYear - Majority of employes spend 2-3 month of training time last year
#
# WorkLifeBalance - The company has average work life balance
#
# YearsInCurrentRole - The employes has average working role years lies in 3-7 years
#
# YearsSinceLastPromotion - showing normal distribution curve roughly
#
# YearsWithCurrManager - Majority of employes has spend approx 3 years with current manager

# %%
#Find the relationship between discrete_features and attrition
for feature in discrete_feature:
    plt.figure(figsize=(20,5))
    sns.countplot(feature, data=dataset, hue="Attrition")

# %% [markdown]
# DistanceFromHome-Employes who have less distance from home are more inclined towards attrition
#
# Education-Type3 are more prone to attrition
#
# EmployeeCount-Irrelevant
#
# EnvironmentSatisfaction-enviornemnt satisfaction is less correlated towrds attrition
#
# JobInvolvement-Employes who are involved in max job invlvemnet are less prone towards Attrition
#
# JobLevel-Employes with the increase in joblevel people become less inclined towards attrition
#
# JobSatisfaction- less correlated towards attrition
#
# NumCompaniesWorked-Employes with minimum number of companies worked are more inclined towrds attrition
#
# PercentSalaryHike-Employes with minimum % of alary Hike are more inclined towrds attrition
#
# PerformanceRating-Employes with great performance are less inclined towards attrition
#
# RelationshipSatisfaction-it is less correlated towards attrition
#
# StandardHours-Irrelevant
#
# StockOptionLevel-Employes wiyh minimum stock optional leval are more prone to attrition
#
# TrainingTimesLastYear-Employes with average Training time last year are more inclined towards attrition
#
# WorkLifeBalance-Employees with average work life balance are more prone towards attrition
#
# YearsInCurrentRole-New employes are more inclined towards attrition
#
# YearsSinceLastPromotion-Employes with minimum years since last promotion are more inclined towards attrition
#
# YearsWthCurrManager-With increase in years with curr manager attrition probability decresses

# %%
#continuous feature
continuous_feature = [feature for feature in numerical_features if feature not in discrete_feature]
print("Continuous Variable Count : {}".format(len(continuous_feature)))
# Out:
# Continuous Variable Count : 8

# %%
dataset[continuous_feature].head()
# Out:
#    Age  DailyRate  EmployeeNumber  HourlyRate  MonthlyIncome  MonthlyRate  \
# 0   41       1102               1          94           5993        19479
# 1   49        279               2          61           5130        24907
# 2   37       1373               4          92           2090         2396
# 3   33       1392               5          56           2909        23159
# 4   27        591               7          40           3468        16632
#
#    TotalWorkingYears  YearsAtCompany
# 0                  8               6
# 1                 10              10
# 2                  7               0
# 3                  8               8
# 4                  6               2

# %%
#Analyzing the continuous features  
for feature in continuous_feature:
    plt.figure(figsize=(10,6))
    sns.set(style = "whitegrid")
    sns.distplot(dataset[feature],kde=True)
    plt.show()
    print()

# %% [markdown]
# Age - Majority of the employes are in between 27-40 age group
#
# DailyRate - The data is equally distributed from 125 to 1500
#
# EmployeeNumber - The data is spred form 0 to 2000
#
# HourlyRate - The rate ranges from 30 to 100
#
# MonthlyIncome - Salary is also less for majority of employees
#
# MonthlyRate  - The rate is equally distributed b/w 5k-25k
#
# TotalWorkingYears - The majority of employes has working experiance of 5-10 years
#
# YearsAtCompany - The average work year in company is less than 10

# %%
##Find the relationship between continuous_features and attrition
for feature in continuous_feature:
    plt.figure(figsize=(20,5))
    sns.countplot(feature, data=dataset, hue="Attrition")

# %% [markdown]
# Age - Employes in the age group of 24 t0 35 ar emore inclined towards attrition
#
# DailyRate - Irrelevant
#
# EmployeeNumber - Irrelevant
#
# HourlyRate - It'ss less correlated toward attrition
#
# MonthlyIncome - Irrelevant
#
# MonthlyRate - Irrelevant
#
# TotalWorkingYears - Employes with less workin year are more inclined towards attrition
#
# Years at Company - Employes with less year at company are more inclined towards attrition

# %%
#categorical Values
categorical_feature = [feature for feature in dataset.columns if dataset[feature].dtypes=='O']
print('Categorical Count : {}'.format(len(categorical_feature)))
# Out:
# Categorical Count : 9

# %%
dataset[categorical_feature].head()
# Out:
#   Attrition     BusinessTravel              Department EducationField  Gender  \
# 0       Yes      Travel_Rarely                   Sales  Life Sciences  Female
# 1        No  Travel_Frequently  Research & Development  Life Sciences    Male
# 2       Yes      Travel_Rarely  Research & Development          Other    Male
# 3        No  Travel_Frequently  Research & Development  Life Sciences  Female
# 4        No      Travel_Rarely  Research & Development        Medical    Male
#
#                  JobRole MaritalStatus Over18 OverTime
# 0        Sales Executive        Single      Y      Yes
# 1     Research Scientist       Married      Y       No
# 2  Laboratory Technician        Single      Y      Yes
# 3     Research Scientist       Married      Y      Yes
# 4  Laboratory Technician       Married      Y       No

# %%
#cardinality values
for feature in categorical_feature:
    print(feature)
    print("------------------------")
    print(dataset[feature].value_counts())
    plt.figure(figsize=(20,6))
    sns.countplot(feature,data=dataset)
    plt.show()
    print()
# Out:
# Attrition
# ------------------------
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# BusinessTravel
# ------------------------
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# Department
# ------------------------
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# EducationField
# ------------------------
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# Gender
# ------------------------
# Male      882
# Female    588
# Name: Gender, dtype: int64
# JobRole
# ------------------------
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# ...

# %% [markdown]
# BusinessTravel - Most of the employees rarely travel
#
# Department - The Research and Development Department have most of the employes
#
# EducationField - Most of the employes belong to Life sciences and Medical background
#
# Gender - Majority of the employes are male but the number of female employes are also good in number
#
# JobRole - Sales Executive employes are highest
#
# MartialStatus - Most of the employes are married
#
# Over18 - Al the employes are over 18
#
# OverTime - there are very less occurence of over time

# %%
##Find the relationship between categorical_features and attrition
for feature in categorical_feature:
    plt.figure(figsize=(20,5))
    sns.countplot(feature, data=dataset, hue="Attrition")

# %% [markdown]
# BuinessTravel-Employees who travel rarely are inclined towards attrition
#
# Department-Research and Development Department are more prone to attrition
#
# EducationField-Employes rom Life Sciences and Medical Background are inclined towards attrition
#
# Gender-Male employes are more prone to attrition
#
# JobRole-Laboratory Technician and ales Executive are more inclined towards attrition
#
# MartialStatus-Employes who are single are more inclined towards attrition and employes who are divorced are les inclined towards attrition
#
# Over18-Doesn't matter-Irrelevant
#
# OverTime-Employees doing overtime are  slightly more prone towards attrition

# %%
#labeling the categorical values by label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for feature in categorical_feature:
    dataset[feature]=le.fit_transform(dataset[feature].values)

# %%
#checking the coffecient
cor=dataset.corr()
cor
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeCount                  NaN        NaN             NaN        NaN
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# ...

# %%
#using heatmap 
plt.figure(figsize=(25,25))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
#since there are to many columns, sorting correlation with attrition in desending order
dataset.corr()["Attrition"].sort_values(ascending=False)
# Out:
# Attrition                   1.000000
# OverTime                    0.246118
# MaritalStatus               0.162070
# DistanceFromHome            0.077924
# JobRole                     0.067151
# Department                  0.063991
# NumCompaniesWorked          0.043494
# Gender                      0.029453
# EducationField              0.026846
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# BusinessTravel              0.000074
# HourlyRate                 -0.006846
# EmployeeNumber             -0.010577
# PercentSalaryHike          -0.013478
# Education                  -0.031373
# YearsSinceLastPromotion    -0.033019
# RelationshipSatisfaction   -0.045872
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# JobInvolvement             -0.130016
# YearsAtCompany             -0.134392
# ...

# %% [markdown]
# Employe count ,over18 and standardhours are having nan corelation with attrition.
#
# performance rating, buisness travel and hourly rate are close to zero
#
# droping these values

# %%
dataset.drop(["EmployeeCount","Over18","StandardHours","PerformanceRating","BusinessTravel","HourlyRate"],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#    Age  Attrition  DailyRate  Department  DistanceFromHome  Education  \
# 0   41          1       1102           2                 1          2
# 1   49          0        279           1                 8          1
# 2   37          1       1373           1                 2          2
# 3   33          0       1392           1                 3          4
# 4   27          0        591           1                 2          1
#
#    EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0               1               1                        2       0
# 1               1               2                        3       1
# 2               4               4                        4       1
# 3               1               5                        4       0
# 4               3               7                        1       1
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# ...

# %%
dataset.shape
# Out:
# (1470, 29)

# %% [markdown]
# now there are 29 columns

# %%
#ploting boxplot to check oultiers
fig, ax=plt.subplots(ncols=5,nrows=6, figsize=(20,20))
index=0
ax=ax.flatten()
for col, value in dataset.items():
    if col != "type":
        sns.boxplot(value, ax=ax[index])
        index+=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %% [markdown]
# there ar emany columns with outliers like yearswithcurmanager, yearssincelastpromotion,totalworkingyears,yearsatcompany,monthlyincome,
#
# there are outliers in categorical value also.
#
# with zscore method we are lossing more than 10 percent of the data so we will use IQR method to treat outliers

# %%
#craeting a histogram function
def histogram(data_frame,feature_name):
    plt.figure(figsize=(15,6))
    sns.set(style = "whitegrid")
    sns.distplot(data_frame[feature_name],kde=True)

# %%
#fixing the outlier
#function to apply IQR
#Also there can be no negative value so the lower bridge is replaced with 25th percentile for the number =<0
def outlier_IQR(data_frame,feature_name):
    histogram(data_frame,feature_name)
    IQR = data_frame[feature_name].quantile(0.75)-data_frame[feature_name].quantile(0.25)
    lower_bridge = data_frame[feature_name].quantile(0.25)
    upper_bridge = data_frame[feature_name].quantile(0.75)+(IQR*1.5)
    dataset.loc[data_frame[feature_name]>=upper_bridge,feature_name]=upper_bridge
    dataset.loc[data_frame[feature_name]<=0,feature_name]=lower_bridge
    histogram(data_frame,feature_name)

# %%
#MonthlyIncome
outlier_IQR(dataset,"MonthlyIncome")

# %%
#TotalWorkingYears
outlier_IQR(dataset,"TotalWorkingYears")

# %%
#NumCompaniesWorked
outlier_IQR(dataset,"NumCompaniesWorked")

# %%
#YearsAtCompany
outlier_IQR(dataset,"YearsAtCompany")

# %%
#YearsInCurrentRole
outlier_IQR(dataset,"YearsInCurrentRole")

# %%
#YearsSinceLastPromotion
outlier_IQR(dataset,"YearsSinceLastPromotion")

# %%
#YearsWithCurrManager
outlier_IQR(dataset,"YearsWithCurrManager")

# %%
#ploting boxplot after removing outliers
fig, ax=plt.subplots(ncols=5,nrows=6, figsize=(20,20))
index=0
ax=ax.flatten()
for col, value in dataset.items():
    if col != "type":
        sns.boxplot(value, ax=ax[index])
        index+=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %% [markdown]
# we have successfully treated the outliers

# %%
#checking for skewness
dataset.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.168595
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.118062
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           0.879074
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# ...

# %% [markdown]
# there are skewness in some columns

# %%
#spliting data in x and y
x=dataset.drop("Attrition", axis=1)
x
# Out:
#       Age  DailyRate  Department  DistanceFromHome  Education  EducationField  \
# 0      41       1102           2                 1          2               1
# 1      49        279           1                 8          1               1
# 2      37       1373           1                 2          2               4
# 3      33       1392           1                 3          4               1
# 4      27        591           1                 2          1               3
# ...   ...        ...         ...               ...        ...             ...
# 1465   36        884           1                23          2               3
# 1466   39        613           1                 6          1               3
# 1467   27        155           1                 4          3               1
# 1468   49       1023           2                 2          3               3
# 1469   34        628           1                 8          3               3
#
# ...

# %%
y=dataset["Attrition"]
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
#treating skewness with power transform
from sklearn.preprocessing import power_transform
dataset_new=power_transform(x)
dataset_new=pd.DataFrame(dataset_new,columns=x.columns)

# %%
#checking for skewness
dataset_new.skew()
# Out:
# Age                        -0.007603
# DailyRate                  -0.196160
# Department                  0.013801
# DistanceFromHome           -0.007468
# Education                  -0.099881
# EducationField             -0.008386
# EmployeeNumber             -0.288025
# EnvironmentSatisfaction    -0.205395
# Gender                     -0.408665
# JobInvolvement             -0.020365
# JobLevel                    0.103624
# JobRole                    -0.319659
# JobSatisfaction            -0.212815
# MaritalStatus              -0.156911
# MonthlyIncome               0.000000
# MonthlyRate                -0.184087
# NumCompaniesWorked          0.297139
# OverTime                    0.964489
# PercentSalaryHike           0.116250
# RelationshipSatisfaction   -0.193634
# StockOptionLevel            0.087019
# TotalWorkingYears          -0.025062
# TrainingTimesLastYear       0.058058
# WorkLifeBalance            -0.012286
# YearsAtCompany             -0.017723
# ...

# %%
x=dataset_new
x
# Out:
#            Age  DailyRate  Department  DistanceFromHome  Education  \
# 0     0.522140   0.759289    1.377454         -1.494085  -0.916940
# 1     1.276411  -1.334597   -0.472127          0.243416  -1.771185
# 2     0.102091   1.340365   -0.472127         -1.031215  -0.916940
# 3    -0.353971   1.379936   -0.472127         -0.700347   1.082871
# 4    -1.123755  -0.453941   -0.472127         -1.031215  -1.771185
# ...        ...        ...         ...               ...        ...
# 1465 -0.008279   0.264672   -0.472127          1.407126  -0.916940
# 1466  0.316210  -0.397219   -0.472127         -0.050827  -1.771185
# 1467 -1.123755  -1.751713   -0.472127         -0.442291   0.040522
# 1468  1.276411   0.583235    1.377454         -1.031215   0.040522
# 1469 -0.236188  -0.358845   -0.472127          0.243416   0.040522
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction    Gender  \
# 0          -0.960488       -2.164110                -0.706596 -1.224745
# ...

# %%
#the dependent varible is unbalenced
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
#using upsampling to balance the data
from imblearn.over_sampling import SMOTE
oversample=SMOTE()
#data transformation
x,y = oversample.fit_resample(x,y)
#balanced data
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
#importing libraries for model building
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
#spliting the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.35, random_state=300)

# %%
print(x_train)
print(x_train.shape)
# Out:
#            Age  DailyRate  Department  DistanceFromHome  Education  \
# 1035 -0.597882   1.392403   -2.549689          0.243416  -0.916940
# 2142 -0.198687  -0.211049   -0.144302          1.299990   0.898122
# 2066 -2.426756  -0.404600    1.377454          0.930828   0.040522
# 255  -1.408993  -0.215103   -0.472127         -1.494085   0.040522
# 950  -0.597882  -0.464312    1.377454         -1.031215   1.082871
# ...        ...        ...         ...               ...        ...
# 2139  0.908650  -0.933551    1.377454          0.405142   0.103426
# 1749 -1.264126   1.307041   -0.472127          1.502002   0.041231
# 1033 -0.597882   1.489594   -0.472127         -1.494085   2.198276
# 1738  0.506594   0.335486   -0.472127         -0.200445  -0.916940
# 1233 -0.724322   0.049148   -0.472127          0.995187  -1.771185
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction    Gender  \
# 1035        0.697390        0.746763                 1.209516 -1.224745
# ...

# %%
print(y_train)
print(y_train.shape)
# Out:
# 1035    0
# 2142    1
# 2066    1
# 255     0
# 950     0
#        ..
# 2139    1
# 1749    1
# 1033    1
# 1738    1
# 1233    0
# Name: Attrition, Length: 1602, dtype: int32
# (1602,)

# %%
print(x_test)
print(x_test.shape)
# Out:
#            Age  DailyRate  Department  DistanceFromHome  Education  \
# 984  -0.987055  -0.089079    1.377454          1.548529   0.040522
# 527  -0.474486   0.369125    1.377454          0.479509   0.040522
# 622  -0.474486  -1.895254    1.377454          0.764593   1.082871
# 526   0.316210  -0.949802   -0.472127         -1.031215   1.082871
# 2019  0.554987   1.215133    1.377454          0.109358  -0.092135
# ...        ...        ...         ...               ...        ...
# 109  -1.870768  -0.603502   -0.472127          0.923081   0.040522
# 720  -0.724322  -1.814667   -0.472127          1.356120   0.040522
# 1315 -0.008279  -0.887553   -0.472127         -1.031215   1.082871
# 1757 -0.874473  -0.769518   -0.472127          1.301901   0.040522
# 13   -0.236188   1.283889   -0.472127          1.188948  -0.916940
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction    Gender  \
# 984        -0.960488        0.642915                 0.208597  0.816497
# ...

# %%
print(y_test)
print(y_test.shape)
# Out:
# 984     0
# 527     0
# 622     0
# 526     0
# 2019    1
#        ..
# 109     0
# 720     1
# 1315    0
# 1757    1
# 13      0
# Name: Attrition, Length: 864, dtype: int32
# (864,)

# %%
# function to train, test and performance check 
def model(name):
    model=name()
    model.fit(x_train,y_train)
    predict=model.predict(x_test)
    print("""The classification report is:
    """,classification_report(y_test, predict))
       
    print("The accuracy score is: ", accuracy_score(y_test,predict))
    
    
    print("""The confusion matrix is:
    
    """,confusion_matrix(y_test,predict))

# %%
#LogisticRegression
model(LogisticRegression)
# Out:
# The classification report is:
#                    precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80       454
#            1       0.76      0.83      0.79       410
#
#     accuracy                           0.80       864
#    macro avg       0.80      0.80      0.80       864
# weighted avg       0.80      0.80      0.80       864
#
# The accuracy score is:  0.7951388888888888
# The confusion matrix is:
#
#      [[348 106]
#  [ 71 339]]

# %%
print(cross_val_score(LogisticRegression(),x,y,cv=10).mean())
# Out:
# 0.7778084987327606

# %%
#DecisionTreeClassifier
model(DecisionTreeClassifier)
# Out:
# The classification report is:
#                    precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       454
#            1       0.81      0.87      0.84       410
#
#     accuracy                           0.84       864
#    macro avg       0.84      0.84      0.84       864
# weighted avg       0.84      0.84      0.84       864
#
# The accuracy score is:  0.8402777777777778
# The confusion matrix is:
#
#      [[368  86]
#  [ 52 358]]

# %%
print(cross_val_score(DecisionTreeClassifier(),x,y,cv=10).mean())
# Out:
# 0.8239919686646259

# %%
#RandomForestClassifier
model(RandomForestClassifier)
# Out:
# The classification report is:
#                    precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       454
#            1       0.95      0.93      0.94       410
#
#     accuracy                           0.94       864
#    macro avg       0.94      0.94      0.94       864
# weighted avg       0.94      0.94      0.94       864
#
# The accuracy score is:  0.9421296296296297
# The confusion matrix is:
#
#      [[433  21]
#  [ 29 381]]

# %%
print(cross_val_score(RandomForestClassifier(),x,y,cv=10).mean())
# Out:
# 0.9404496231197129

# %%
#SVC
model(SVC)
# Out:
# The classification report is:
#                    precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       454
#            1       0.88      0.92      0.90       410
#
#     accuracy                           0.90       864
#    macro avg       0.90      0.90      0.90       864
# weighted avg       0.90      0.90      0.90       864
#
# The accuracy score is:  0.9016203703703703
# The confusion matrix is:
#
#      [[401  53]
#  [ 32 378]]

# %%
print(cross_val_score(SVC(),x,y,cv=10).mean())
# Out:
# 0.9164856324676606

# %%
#Naive Bayes
model(GaussianNB)
# Out:
# The classification report is:
#                    precision    recall  f1-score   support
#
#            0       0.74      0.67      0.70       454
#            1       0.67      0.74      0.70       410
#
#     accuracy                           0.70       864
#    macro avg       0.70      0.70      0.70       864
# weighted avg       0.71      0.70      0.70       864
#
# The accuracy score is:  0.7013888888888888
# The confusion matrix is:
#
#      [[302 152]
#  [106 304]]

# %%
print(cross_val_score(GaussianNB(),x,y,cv=10).mean())
# Out:
# 0.7088542180968369

# %%
#KNeighborsClassifier
model(KNeighborsClassifier)
# Out:
# The classification report is:
#                    precision    recall  f1-score   support
#
#            0       0.97      0.62      0.75       454
#            1       0.70      0.98      0.81       410
#
#     accuracy                           0.79       864
#    macro avg       0.83      0.80      0.78       864
# weighted avg       0.84      0.79      0.78       864
#
# The accuracy score is:  0.7881944444444444
# The confusion matrix is:
#
#      [[280 174]
#  [  9 401]]

# %%
print(cross_val_score(KNeighborsClassifier(),x,y,cv=10).mean())
# Out:
# 0.8025147296007372

# %%
#in RandomForestClassifier model the accurcay score is high , also the differance in crossvalscore and accuracy score is minimum so RandomForestClassifier is our best model

# %%
#parameters for hyperparametertuning
parameter = {
    "n_estimators":[100,120,140,150],
    "criterion":['gini','entropy'],
    "max_depth":range(40),
    "min_samples_leaf":range(5)
            }

# %%
#using GridSearchCV for Hyper parameter tunning
gcv=GridSearchCV(RandomForestClassifier(),parameter,cv=10)

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(0, 40),
#                          'min_samples_leaf': range(0, 5),
#                          'n_estimators': [100, 120, 140, 150]})

# %%
#checking best parameters
gcv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 17,
#  'min_samples_leaf': 1,
#  'n_estimators': 150}

# %%
#building final model
best_model=RandomForestClassifier(criterion='entropy',n_estimators=150,min_samples_leaf=1,max_depth=17)
best_model.fit(x_train,y_train)
pred=best_model.predict(x_test)
print("""The classification report is:
       """,classification_report(y_test, pred))
       
print("The accuracy score is: ", accuracy_score(y_test,pred))
    
    
print("""The confusion matrix is: 
      """,confusion_matrix(y_test,pred))
# Out:
# The classification report is:
#                       precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       454
#            1       0.95      0.94      0.95       410
#
#     accuracy                           0.95       864
#    macro avg       0.95      0.95      0.95       864
# weighted avg       0.95      0.95      0.95       864
#
# The accuracy score is:  0.9502314814814815
# The confusion matrix is:
#        [[435  19]
#  [ 24 386]]

# %%
#auc_roc curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
rfc_roc_auc=roc_auc_score(y_test, best_model.predict(x_test))
fpr, tpr,thresholds=roc_curve(y_test,best_model.predict(x_test))
plt.figure
plt.plot(fpr,tpr, label="SVC (area=%0.2f)" % rfc_roc_auc)
plt.plot([0,1],[0,1],"r--")
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC")
plt.legend(loc="lower right")
plt.savefig("SVC_ROC")
plt.show()

# %%
#around 95 percent of the area is covered, so our model is working good

# %%
#savingThemodel
import joblib
joblib.dump(best_model,"HR_Attrition.pkl")
# Out:
# ['HR_Attrition.pkl']
